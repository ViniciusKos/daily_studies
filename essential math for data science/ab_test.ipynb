# %% [raw]
# Type II error is the likelihood failing to reject a false null hypothesis. Don't detected an effect

# %%
import numpy as np
import pandas as pd
from scipy.stats import binom
n = 137
p = 0.4
probs = []
for k in range(n):
    probability = binom.pmf(k, n, p)
    probs.append(probability)

pd.Series(probs).plot()
# Out:
# <Axes: >

# %%
np.sum(probs[50:])
# Out:
# 0.8220955881474252

# %%
from scipy.stats import beta
a = 15
b = 4
p = beta.cdf(.90, a, b) - beta.cdf(.80, a, b)
# 0.33863336200000016
print(p)
# Out:
# 0.40077770002959456

# %%
import numpy as np
from scipy.stats import beta
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
a =  8
b = 2
x = np.arange(0.01, 1.01, 0.01)
y = beta.pdf(x,a,b)
plt.plot(x,y)

# %%
1-beta.cdf(0.5, 8, 2)
# Out:
# 0.98046875

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-10, 100, 0.001)
# Mean = 0, SD = 2.
plt.plot(x_axis, norm.pdf(x_axis,42,8))
plt.show()

# %%
norm.cdf(30,42,8) - norm.cdf(20,42,8)
# Out:
# 0.0638274380338035

# %%
from math import sqrt
from scipy.stats import norm
def critical_z_value(p, mean=0.0, std=1.0):
    norm_dist = norm(loc=mean, scale=std)
    left_area = (1.0 - p) / 2.0
    right_area = 1.0 - ((1.0 - p) / 2.0)
    return norm_dist.ppf(left_area), norm_dist.ppf(right_area)

# %%
critical_z_value(0.99)
# Out:
# (-2.5758293035489004, 2.5758293035489004)

# %% [markdown]
# # Chapter 2.0 - Probability

# %%
from scipy.stats import beta, binom, norm
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# beta.cdf(0.5, 15, 4)

# %%
passengers = 137
np.sum([binom.pmf(i,0.4,50) for i in range(passengers+1)])

# %%
1-binom.cdf(49,137,0.4)
# Out:
# 0.8220955881474242

# %%
a =  6
b = 2
x = np.arange (0.01, 1, 0.01)
y = beta.pdf(x,a,b)
plt.plot(x,y)

# %%
n = 10
p = 0.9
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ] 
# plotting the graph  
plt.bar(r_values, dist) 
plt.show()

# %%
1-binom.cdf(8,10, 0.9)
# Out:
# 0.7360989291000002

# %% [markdown]
# # 3.0 Descriptive and inferential statistics

# %%
norm.cdf(30, 42, 8) - norm.cdf(20, 42, 8)
# Out:
# 0.0638274380338035

# %% [raw]
# I am skeptical that my 3D printer filament is not 1.75 mm in average diameter
# as advertised. I sampled 34 measurements with my tool. The sample mean is
# 1.715588 and the sample standard deviation is 0.029252.
# What is the 99% confidence interval for the mean of my entire spool of filament?

# %%
standard_normal = norm(loc=0, scale=1)
left_tail_area = (1-0.99)/2
right_tail_area = 1-left_tail_area

# %%
standard_normal.ppf(left_tail_area)
# Out:
# -2.5758293035489004

# %%
standard_normal.ppf(right_tail_area)
# Out:
# 2.5758293035489004

# %%
from math import sqrt
from scipy.stats import norm
def critical_z_value(p, mean=0.0, std=1.0):
    norm_dist = norm(loc=mean, scale=std)
    left_area = (1.0 - p) / 2.0
    right_area = 1.0 - ((1.0 - p) / 2.0)
    return norm_dist.ppf(left_area), norm_dist.ppf(right_area)

# %%
critical_z_value(0.95)
# Out:
# (-1.959963984540054, 1.959963984540054)

# %%
def ci_large_sample(p, sample_mean, sample_std, n):
    # Sample size must be greater than 30
    lower, upper = critical_z_value(p)
    lower_ci = lower * (sample_std / sqrt(n))
    upper_ci = upper * (sample_std / sqrt(n))
    return sample_mean + lower_ci, sample_mean + upper_ci
print(ci_large_sample(p=.99, sample_mean=1.715588,
sample_std=0.029252, n=34))

# %%
from scipy import stats

# %%
from scipy.stats import norm
x1 = norm.ppf(.025, 10345, 552)
x1
# Out:
# 9263.09988053389

# %%
from scipy.stats import norm
x1 = norm.ppf(1-.025, 10345, 552)
x1
# Out:
# 11426.90011946611

# %%
norm

# %%
(1-norm.cdf(11641, 10345, 552))*2
# Out:
# 0.01888333596496139

# %%
from scipy.stats import t, norm
# get critical value range for 95% confidence
# with a sample size of 25
n = 25
lower = t.ppf(.025, df=n-1)
upper = t.ppf(.975, df=n-1)
print(lower, upper)
# Out:
# -2.063898561628021 2.0638985616280205

# %%
t.cdf(-1.9599, df=24, loc=0, scale=1)
# Out:
# 0.03085918338434509

# %%
norm_dist = norm(loc=0, scale=1)
norm_dist.ppf(0.025)
# Out:
# -1.9599639845400545

# %%
norm_dist.ppf(0.975)
# Out:
# 1.959963984540054

# %%
from math import sqrt
from scipy.stats import norm
def critical_z_value(p, mean=0.0, std=1.0):
    norm_dist = norm(loc=mean, scale=std)
    left_area = (1.0 - p) / 2.0
    right_area = 1.0 - ((1.0 - p) / 2.0)
    return norm_dist.ppf(left_area), norm_dist.ppf(right_area)

# %%
norm_dist = norm(loc = 42, scale = 8)
norm_dist.cdf(30) - norm_dist.cdf(20)
# Out:
# 0.0638274380338035

# %%
standard_normal = norm(loc=0, scale=1)
standard_normal.ppf(0.005)
# Out:
# -2.575829303548901

# %% [markdown]
# # Chapter 5 Linear Regression

# %%
df = pd.read_csv("https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/regression/linear_normal.csv")
df.head()
# Out:
#    x          y
# 0  1 -13.115843
# 1  2  25.806547
# 2  3  -5.017285
# 3  4  20.256415
# 4  5   4.075003

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Simulate the data
# Rows represent the number of users who clicked ('Yes') and did not click ('No')
# Columns represent Layouts A and B
data = np.array([[200, 210],  # Clicked 'Yes'
                 [300, 290]]) # Clicked 'No'

# Perform the chi-square test
chi2, p_value, dof, expected = chi2_contingency(data)

print("Chi-squared Test Statistic:", chi2)
print("p-value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:\n", expected)
# Out:
# Chi-squared Test Statistic: 0.33484911120297645
# p-value: 0.5628176105813951
# Degrees of Freedom: 1
# Expected Frequencies:
#  [[205. 205.]
#  [295. 295.]]
